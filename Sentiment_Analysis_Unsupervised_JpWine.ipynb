# %% [markdown]
# # Japanese Whisky Sentiment Analysis (unsupervised learning)

# %% [markdown]
# ****Introduction****
#
# Here, we explored the binary sentiment (positive & negative) of Jepanese Whisky reviews using unsupervised machine learning method, then counted the numbers of positive & negative reviews of the whole dataset and each whisky brands to generate business insights
#
# ****Dataset****
#
# This dataset contains 1130 customers’ reviews for 4 Japanese whiskey brands. The data is inputed from the CSV file "japanese_whisky_revie.csv"

# %% [markdown]
# ****Initialization****

# %% [markdown]
# Set the path to the folder containing the data:

# %%
path = '/Users/93754/OneDrive/documents/MGT561 text mining/team project/'

# %% [markdown]
# Run functions in Text_Normalization_Function.ipynb for text pre-processing

# %%
# %run ./Text_Normalization_Function.ipynb
# Out:
# Collecting html.parser
# Requirement already satisfied: ply in c:\users\93754\anaconda3\lib\site-packages (from html.parser) (3.11)
# Installing collected packages: html.parser
# Successfully installed html.parser
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: pattern3 in c:\users\93754\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: pdfminer.six in c:\users\93754\anaconda3\lib\site-packages (from pattern3) (20181108)
# Requirement already satisfied: beautifulsoup4 in c:\users\93754\anaconda3\lib\site-packages (from pattern3) (4.6.0)
# Requirement already satisfied: pdfminer3k in c:\users\93754\anaconda3\lib\site-packages (from pattern3) (1.3.1)
# Requirement already satisfied: simplejson in c:\users\93754\anaconda3\lib\site-packages (from pattern3) (3.16.0)
# Requirement already satisfied: cherrypy in c:\users\93754\anaconda3\lib\site-packages (from pattern3) (18.1.1)
# Requirement already satisfied: docx in c:\users\93754\anaconda3\lib\site-packages (from pattern3) (0.2.4)
# Requirement already satisfied: feedparser in c:\users\93754\anaconda3\lib\site-packages (from pattern3) (5.2.1)
# Requirement already satisfied: pycryptodome in c:\users\93754\anaconda3\lib\site-packages (from pdfminer.six->pattern3) (3.8.1)
# Requirement already satisfied: six in c:\users\93754\anaconda3\lib\site-packages (from pdfminer.six->pattern3) (1.11.0)
# Requirement already satisfied: sortedcontainers in c:\users\93754\anaconda3\lib\site-packages (from pdfminer.six->pattern3) (1.5.10)
# Requirement already satisfied: ply>=3.4 in c:\users\93754\anaconda3\lib\site-packages (from pdfminer3k->pattern3) (3.11)
# Requirement already satisfied: pytest>=2.0 in c:\users\93754\anaconda3\lib\site-packages (from pdfminer3k->pattern3) (3.5.1)
# Requirement already satisfied: more-itertools in c:\users\93754\anaconda3\lib\site-packages (from cherrypy->pattern3) (4.1.0)
# Requirement already satisfied: zc.lockfile in c:\users\93754\anaconda3\lib\site-packages (from cherrypy->pattern3) (1.4)
# Requirement already satisfied: pywin32; sys_platform == "win32" in c:\users\93754\anaconda3\lib\site-packages (from cherrypy->pattern3) (223)
# Requirement already satisfied: cheroot>=6.2.4 in c:\users\93754\anaconda3\lib\site-packages (from cherrypy->pattern3) (6.5.4)
# Requirement already satisfied: portend>=2.1.1 in c:\users\93754\anaconda3\lib\site-packages (from cherrypy->pattern3) (2.4)
# Requirement already satisfied: lxml in c:\users\93754\anaconda3\lib\site-packages (from docx->pattern3) (4.2.1)
# Requirement already satisfied: Pillow>=2.0 in c:\users\93754\anaconda3\lib\site-packages (from docx->pattern3) (5.1.0)
# Requirement already satisfied: py>=1.5.0 in c:\users\93754\anaconda3\lib\site-packages (from pytest>=2.0->pdfminer3k->pattern3) (1.5.3)
# Requirement already satisfied: setuptools in c:\users\93754\anaconda3\lib\site-packages (from pytest>=2.0->pdfminer3k->pattern3) (39.1.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\93754\anaconda3\lib\site-packages (from pytest>=2.0->pdfminer3k->pattern3) (18.1.0)
# Requirement already satisfied: pluggy<0.7,>=0.5 in c:\users\93754\anaconda3\lib\site-packages (from pytest>=2.0->pdfminer3k->pattern3) (0.6.0)
# Requirement already satisfied: colorama in c:\users\93754\anaconda3\lib\site-packages (from pytest>=2.0->pdfminer3k->pattern3) (0.3.9)
# Requirement already satisfied: backports.functools-lru-cache in c:\users\93754\anaconda3\lib\site-packages (from cheroot>=6.2.4->cherrypy->pattern3) (1.5)
# Requirement already satisfied: tempora>=1.8 in c:\users\93754\anaconda3\lib\site-packages (from portend>=2.1.1->cherrypy->pattern3) (1.14)
# Requirement already satisfied: jaraco.functools>=1.20 in c:\users\93754\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern3) (2.0)
# Requirement already satisfied: pytz in c:\users\93754\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern3) (2018.4)
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: pyLDAvis in c:\users\93754\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (1.14.3)
# Requirement already satisfied: pandas>=0.17.0 in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (0.23.0)
# Requirement already satisfied: future in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (0.17.1)
# Requirement already satisfied: numexpr in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (2.6.5)
# Requirement already satisfied: scipy>=0.18.0 in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: pytest in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (3.5.1)
# Requirement already satisfied: wheel>=0.23.0 in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (0.31.1)
# Requirement already satisfied: funcy in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (1.11)
# Requirement already satisfied: joblib>=0.8.4 in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (0.13.2)
# Requirement already satisfied: jinja2>=2.7.2 in c:\users\93754\anaconda3\lib\site-packages (from pyLDAvis) (2.10)
# Requirement already satisfied: pytz>=2011k in c:\users\93754\anaconda3\lib\site-packages (from pandas>=0.17.0->pyLDAvis) (2018.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\93754\anaconda3\lib\site-packages (from pandas>=0.17.0->pyLDAvis) (2.7.3)
# Requirement already satisfied: py>=1.5.0 in c:\users\93754\anaconda3\lib\site-packages (from pytest->pyLDAvis) (1.5.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\93754\anaconda3\lib\site-packages (from pytest->pyLDAvis) (1.11.0)
# Requirement already satisfied: setuptools in c:\users\93754\anaconda3\lib\site-packages (from pytest->pyLDAvis) (39.1.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\93754\anaconda3\lib\site-packages (from pytest->pyLDAvis) (18.1.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\93754\anaconda3\lib\site-packages (from pytest->pyLDAvis) (4.1.0)
# Requirement already satisfied: pluggy<0.7,>=0.5 in c:\users\93754\anaconda3\lib\site-packages (from pytest->pyLDAvis) (0.6.0)
# Requirement already satisfied: colorama in c:\users\93754\anaconda3\lib\site-packages (from pytest->pyLDAvis) (0.3.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\93754\anaconda3\lib\site-packages (from jinja2>=2.7.2->pyLDAvis) (1.0)
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  ['<', 'p', '>', 'The', 'circus', 'dog', 'in', 'a', 'plissé', 'skirt', 'jumped', 'over', 'Python', 'who', 'was', "n't", 'that', 'large', ',', 'just', '3', 'feet', 'long.', '<', '/p', '>']
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  <p>The circus dog in a plissé skirt jumped over Python who was not that large, just 3 feet long.</p>
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  [('<', 'a'), ('p', 'n'), ('>', 'v'), ('the', None), ('circus', 'n'), ('dog', 'n'), ('in', None), ('a', None), ('plissé', 'n'), ('skirt', 'n'), ('jumped', 'v'), ('over', None), ('python', 'n'), ('who', None), ('was', 'v'), ("n't", 'r'), ('that', None), ('large', 'a'), (',', None), ('just', 'r'), ('3', None), ('feet', 'n'), ('long.', 'a'), ('<', 'n'), ('/p', 'n'), ('>', 'n')]
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  < p > the circus dog in a plissé skirt jump over python who be n't that large , just 3 foot long. < /p >
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:    p   The circus dog in a plissé skirt jumped over Python who was n t that large   just 3 feet long     p
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  < p > The circus dog plissé skirt jumped Python n't large , 3 feet long. < /p >
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  p The circus dog in a plissé skirt jumped over Python who was n't that large just feet long. /p
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  <p>The circus dog in a plisse skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Original:   ["<p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>", "<p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>"]
#
# Processed:  ['circus dog plisse skirt jump python large foot long', 'circus dog plisse skirt jump python large foot long']

# %% [markdown]
# Import the required modules:

# %%
import pandas as pd
import numpy as np
import sys
import nltk
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# Use the VADER lexicon available in NLTK module:
#
# download the VADER lexicon and set up the sentiment analysis function that uses that lexicon

# %%
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\93754\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# Read in data and slice out the review part

# %%
data = pd.read_csv("japanese_whisky_review.csv")
reviews = np.array(data["Review_Content"])

# %% [markdown]
# ****Define Modeling Function****

# %% [markdown]
# Define the function that scores text using VADER lexicon and returns the polarity score and the binary sentiment indicator (positive or negative).
#
# If "compound" polarity/intensity score > 0.1 then the review is positive. The threshold of 0.1 is the recommended value.

# %%
def analyze_sentiment_vader_lexicon(review, 
                                    threshold = 0.1,
                                    verbose = False):
    
    #pre-process text
    review = normalize_accented_characters(review)
    review = html_parser.unescape(review)
    review = strip_html(review)
    
    #analyze the sentiment for review
    analyzer = SentimentIntensityAnalyzer()
    scores = analyzer.polarity_scores(review)
    
    #get binary sentiment
    binary_sentiment = 'positive' if scores['compound'] >= threshold\
                                   else 'negative'
    
    if verbose:
        
        #display sentiment 
        sentiment_frame = pd.DataFrame([[binary_sentiment, round(scores['compound'], 2)]],
                                        columns=pd.MultiIndex(levels=[['SENTIMENT STATS:'], 
                                                                      ['Binary Sentiment ', 'Polarity Score']], 
                                                              labels=[[0,0],[0,1]]))
        print(sentiment_frame.to_string(index=False))
    
    return binary_sentiment,scores['compound']

# %% [markdown]
# Test the function and display sample results

# %%
for doc_index in range(8):
    print('Review:-')
    print(reviews[doc_index])   
    print()    
    final_sentiment = analyze_sentiment_vader_lexicon(reviews[doc_index],
                                                        threshold=0.1,
                                                        verbose=True)
    print('-'*60)
# Out:
# Review:-
# Dull taste. High price. No finish. Over-hyped and disappointing.
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         negative           -0.8
# ------------------------------------------------------------
# Review:-
# Delicious! sugared red fruits and sweet with a morish, cinnamon, aromatic depth.
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         positive           0.79
# ------------------------------------------------------------
# Review:-
# I am not a whisky expert but i really love the taste. The experience i had i would describe as very comfortable like being snug under a blanket on a cold rainy day. i sip this with my friend through the night and just enjoyed the flavors. That being said, it is more expensive and i feel that for that price, you could get a better whisky. i am not saying this because of the no age but rather, i think you can get more from other scotch for that price. But if you have it in your vault already, its really enjoyable.
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         positive           0.99
# ------------------------------------------------------------
# Review:-
# This is a terrible Yamazaki.  Very young, unsherried, no finish.  The Yamazaki 12 is slightly better.  The new Hibiki NAS "Harmony" is still better and a better value than the Yamazaki 12.  The Limited Edition Yamazakis brought out each year are good value and an excellent every day dram. The Yamazaki 18 is a very good sherry bomb, unfortunately insanely over-priced.  Yamazaki Sherry Cask is one of great bottles, difficult to obtain.  The Yamazaki 25 is in a world of it's own and bears no relation to any of the others.  It is one of the greatest whisky expressions ever created.
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         positive           0.93
# ------------------------------------------------------------
# Review:-
# First time and I like it - fresh but not thin and a sweet depth to it. I know I like a whisky when I can't stop smelling the empty glass!
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         positive           0.43
# ------------------------------------------------------------
# Review:-
# I can’t believe all these commenters who are fawning over this particular reserve. Are they for real? This whisky is nonsensical for its price and unworthy of all the hype that Yamazaki or singke malts have been getting. It’s so coarse it’s doesn’t seem very far removed from lab-grade alcohol. The distiller should never have released this (or do they take their customers for fools?). Disappointment.
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         negative          -0.77
# ------------------------------------------------------------
# Review:-
# My friend brought bottle of this from Japan in 2014-2015 and wes so good. And I haven’t  tried anything better since.
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         positive           0.67
# ------------------------------------------------------------
# Review:-
# Nice. I like some vanilla and this has the goods.
#
# SENTIMENT STATS:
# Binary Sentiment  Polarity Score
#         positive           0.65
# ------------------------------------------------------------

# %% [markdown]
# ****Make Prediction****

# %% [markdown]
# Make prediction on all reviews, and display the first 5 rows of results

# %%
predicted_sentiment = pd.DataFrame([analyze_sentiment_vader_lexicon(review, threshold=0.1)
                     for review in reviews],columns = ['binary sentiment','raw score'])

# %%
predicted_sentiment.head()
# Out:
#   binary sentiment  raw score
# 0         negative    -0.7964
# 1         positive     0.7901
# 2         positive     0.9854
# 3         positive     0.9341
# 4         positive     0.4318

# %% [markdown]
# Count the number of positive & negative reviews

# %%
predicted_sentiment["binary sentiment"].value_counts()
# Out:
# positive    930
# negative    200
# Name: binary sentiment, dtype: int64

# %% [markdown]
# Count the number of positive & negative reviews for of each brands

# %%
df = pd.concat([data,predicted_sentiment],axis=1)
df
# Out:
#       Unnamed: 0                                        Bottle_name     Brand  \
# 0              1  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 1              2  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 2              3  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 3              4  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 4              5  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 5              6  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 6              7  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 7              8  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 8              9  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 9             10  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 10            11  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 11            12  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 12            13  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 13            14  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 14            15  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 15            16  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 16            17  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 17            18  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 18            19  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 19            20  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 20            21  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 21            22  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 22            23  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 23            24  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 24            25  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 25            26  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 26            27  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 27            28  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 28            29  The Yamazaki Single Malt Whisky - Distiller’s ...  Yamazaki
# 1107               Domo Arigato, Taketsuru san.  Domo.          negative
# 1108  Received a bottle of the 12 as a gift and love...         positive
# 1109  I have been a pupil of my sensai for over 10 y...         positive
# 1110  A gift from my wife, who has now warmed to my ...         positive
# 1111  One of the best I ever tasted. Nice X-mas pres...         positive
# 1112  Bought this for my son for Xmas. He's always w...         positive
# 1113  Seriously when I first popped this openI could...         positive
# 1114  I love it. A huge fan of Japanese whiskeys in ...         positive
# 1115  Smooth, rich, fruits, caramel toffee. I can't ...         positive
# 1116                         Rating for previous review         negative
# 1117  The local store had a tasting today of this an...         positive
# 1118  Really nothing of special... is a discrete vat...         positive
# 1119  Your tasting notes are spot on; although, I fe...         positive
# 1120  I've only recently dipped my toe into the worl...         negative
# 1121  Absolutely amazing whisky, with notes of Woodf...         positive
# 1122  Reminded me a little of a more subtle version ...         negative
# 1123  I thoroughly enjoyed my full bottle. Is it eve...         positive
# 1124   I love "Perfect Manhattan" made of This whisky.          positive
# 1125  Really enjoyed the flavour of this whisky... G...         positive
# 1126  Given the slightly racist tone to the guy at t...         negative
# 1127  The particular distillation process makes this...         positive
# 1128  That's probably why the previous poster though...         negative
# 1129  Its like buying a bottle of Grey Goose thinkin...         positive
#
#       raw score
# 0       -0.7964
# 1        0.7901
# 2        0.9854
# 3        0.9341
# 4        0.4318
# 5       -0.7691
# 6        0.6742
# 7        0.6486
# 8        0.2161
# 9        0.6124
# 10       0.3182
# 11       0.9826
# 12       0.6124
# 13      -0.4546
# 14       0.8344
# 15       0.9650
# 16      -0.1548
# 17       0.4754
# 18       0.9856
# 19       0.6369
# 20       0.8370
# 21       0.7717
# 22       0.6344
# 23       0.6403
# 24       0.6179
# 25      -0.3818
# 26       0.5859
# 27       0.3612
# 28       0.6249
# 29       0.4854
# ...         ...
# 1100     0.0000
# 1101     0.9226
# 1102     0.9861
# 1103     0.9063
# 1104     0.7650
# 1105     0.1027
# 1106     0.0000
# 1107     0.0000
# 1108     0.5267
# 1109     0.9710
# 1110     0.9850
# 1111     0.8070
# 1112     0.6908
# 1113     0.6584
# 1114     0.8238
# 1115     0.8312
# 1116     0.0000
# 1117     0.8126
# 1118     0.6115
# 1119     0.8718
# 1120    -0.8210
# 1121     0.7818
# 1122     0.0000
# 1123     0.5563
# 1124     0.8360
# 1125     0.8268
# 1126    -0.0074
# 1127     0.8439
# 1128    -0.1695
# 1129     0.7650
#
# [1130 rows x 7 columns]

# %%
def calnum(group):
    result={'Total_Review':group['binary sentiment'].shape[0],\
            'Num_of_Positive':np.sum(group['binary sentiment']=='positive'),\
           'Num_of_Negative':np.sum(group['binary sentiment']=='negative')}
    return pd.Series(result)

df1=df.groupby(by=['Brand']).apply(calnum)
df1
# Out:
#           Total_Review  Num_of_Positive  Num_of_Negative
# Brand
# Hakushu             85               73               12
# Hibiki             196              163               33
# Nikka              392              329               63
# Yamazaki           457              365               92
